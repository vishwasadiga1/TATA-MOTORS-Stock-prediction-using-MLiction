# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('TATAMOTORS.NS.csv',index_col='Date')
df.tail(180)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-03-01  421.500000  428.000000  421.500000  426.000000  424.676422
# 2023-03-02  426.000000  426.250000  419.549988  420.450012  419.143677
# 2023-03-03  422.600006  430.500000  421.950012  428.000000  426.670197
# 2023-03-06  430.950012  441.450012  430.000000  440.100006  438.732605
# 2023-03-08  439.000000  441.250000  436.100006  439.299988  437.935089
# ...                ...         ...         ...         ...         ...
# 2023-11-17  682.500000  687.650024  679.599976  681.549988  681.549988
# 2023-11-20  682.000000  686.750000  670.700012  674.299988  674.299988
# 2023-11-21  677.000000  683.299988  675.000000  681.700012  681.700012
# 2023-11-22  683.950012  687.349976  676.049988  681.200012  681.200012
# 2023-11-23  683.200012  685.900024  677.049988  679.950012  679.950012
#
#               Volume
# Date
# 2023-03-01   7595114
# 2023-03-02   5661103
# 2023-03-03   8027522
# ...

# %%
df.shape
# Out:
# (249, 6)

# %%
df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df[['Open', 'Close', 'High','Low','Close','Adj Close']].plot(figsize=(20,5))
plt.title(" Tata Motors Stock Plot for Overall Period", fontsize=17)
# Out:
# Text(0.5, 1.0, ' Tata Motors Stock Plot for Overall Period')

# %%
#Top-5 Dates with Highest Stock Price

a = df.sort_values(by='High',ascending= False)
a['High']
# Out:
# Date
# 2023-11-17    687.650024
# 2023-11-22    687.349976
# 2023-11-20    686.750000
# 2023-11-23    685.900024
# 2023-11-16    685.500000
#                  ...
# 2022-12-26    390.700012
# 2022-12-23    390.000000
# 2022-12-29    390.000000
# 2023-01-05    388.750000
# 2023-01-06    388.399994
# Name: High, Length: 249, dtype: float64

# %%
#Top-5 Dates with Lowest Stock Price

b = df.sort_values(by='Low',ascending= True)
b['Low']
# Out:
# Date
# 2022-12-26    375.200012
# 2022-12-23    377.000000
# 2023-01-06    381.000000
# 2023-01-05    382.500000
# 2022-12-29    383.049988
#                  ...
# 2023-11-16    670.900024
# 2023-11-21    675.000000
# 2023-11-22    676.049988
# 2023-11-23    677.049988
# 2023-11-17    679.599976
# Name: Low, Length: 249, dtype: float64

# %%
#Plot for Date vs Close
df[['Close']].plot(figsize=(20,5))
plt.xlabel("Date", fontsize=10)
plt.ylabel("Close", fontsize=10)
plt.title("Tata Motors Stock Prices", fontsize=17)
# Out:
# Text(0.5, 1.0, 'Tata Motors Stock Prices')

# %%
x= df[['Open','High','Low','Adj Close']]
y= df[ 'Close' ]
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
model.score(x,y)
# Out:
# 0.9999646600439434

# %%
df["Model_Prediction"] = model.predict(x)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-11-23  426.850006  429.299988  422.850006  424.049988  422.732452
# 2022-11-24  424.500000  425.250000  420.700012  423.399994  422.084473
# 2022-11-25  425.000000  435.149994  424.000000  433.200012  431.854065
# 2022-11-28  435.000000  440.350006  432.399994  433.250000  431.903900
# 2022-11-29  432.500000  437.899994  429.549988  433.149994  431.804199
# ...                ...         ...         ...         ...         ...
# 2023-11-17  682.500000  687.650024  679.599976  681.549988  681.549988
# 2023-11-20  682.000000  686.750000  670.700012  674.299988  674.299988
# 2023-11-21  677.000000  683.299988  675.000000  681.700012  681.700012
# 2023-11-22  683.950012  687.349976  676.049988  681.200012  681.200012
# 2023-11-23  683.200012  685.900024  677.049988  679.950012  679.950012
#
#               Volume  Model_Prediction
# Date
# 2022-11-23   6568241        424.217564
# ...

# %%
df.head(2)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-11-23  426.850006  429.299988  422.850006  424.049988  422.732452
# 2022-11-24  424.500000  425.250000  420.700012  423.399994  422.084473
#
#              Volume  Model_Prediction
# Date
# 2022-11-23  6568241        424.217564
# 2022-11-24  6768613        423.431192

# %%
import warnings
warnings.simplefilter('ignore')
model.predict([[426.85,429.29,422.85,422.73]])
# Out:
# array([424.21475311])
